# %% [markdown]
# ## Imports and Helper Functions

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# ## Loading and cleaning data

# %%
file = 'aarhus_parking.csv'
df_raw = pd.read_csv(file)

df_raw.head(10)
# Out:
#    vehiclecount               updatetime  _id  totalspaces     garagecode  \
# 0             0  2014-05-22 09:09:04.145    1           65      NORREPORT
# 1             0  2014-05-22 09:09:04.145    2          512    SKOLEBAKKEN
# 2           869  2014-05-22 09:09:04.145    3         1240    SCANDCENTER
# 3            22  2014-05-22 09:09:04.145    4          953         BRUUNS
# 4           124  2014-05-22 09:09:04.145    5          130   BUSGADEHUSET
# 5           106  2014-05-22 09:09:04.145    6          400        MAGASIN
# 6           115  2014-05-22 09:09:04.145    7          210  KALKVAERKSVEJ
# 7           233  2014-05-22 09:09:04.145    8          700        SALLING
# 8             0  2014-05-22 09:39:01.803    9           65      NORREPORT
# 9             0  2014-05-22 09:39:01.803   10          512    SKOLEBAKKEN
#
#             streamtime
# 0  2014-11-03 16:18:44
# 1  2014-11-03 16:18:44
# 2  2014-11-03 16:18:44
# 3  2014-11-03 16:18:44
# 4  2014-11-03 16:18:44
# 5  2014-11-03 16:18:44
# 6  2014-11-03 16:18:44
# 7  2014-11-03 16:18:44
# 8  2014-11-03 16:18:44
# 9  2014-11-03 16:18:44

# %%
df_raw.describe()
# Out:
#        vehiclecount           _id   totalspaces
# count  55264.000000  55264.000000  55264.000000
# mean     192.188387  27667.796468    526.250000
# std      210.500021  15959.295617    388.536895
# min        0.000000      1.000000     65.000000
# 25%       32.000000  13855.750000    190.000000
# 50%       96.000000  27671.500000    456.000000
# 75%      296.000000  41487.250000    763.250000
# max     1464.000000  55303.000000   1240.000000

# %%
df_raw.dtypes
# Out:
# vehiclecount     int64
# updatetime      object
# _id              int64
# totalspaces      int64
# garagecode      object
# streamtime      object
# dtype: object

# %%
df = df_raw.copy()

# %%
# set time columns to datetimes
#df['update_datetime'] = pd.to_datetime(df['updatetime'])
#df['stream_datetime'] = pd.to_datetime(df['streamtime'])

# %%
'''

# extract date and time
df['update_time'] = df['update_datetime'].dt.time
df['update_date'] = df['update_datetime'].dt.date


df['stream_time'] = df['stream_datetime'].dt.time
df['stream_date'] = df['stream_datetime'].dt.date

df = df.drop(columns=['updatetime', 'streamtime'])

'''
# Out:
# "\n\n# extract date and time\ndf['update_time'] = df['update_datetime'].dt.time\ndf['update_date'] = df['update_datetime'].dt.date\n\n\ndf['stream_time'] = df['stream_datetime'].dt.time\ndf['stream_date'] = df['stream_datetime'].dt.date\n\ndf = df.drop(columns=['updatetime', 'streamtime'])\n\n"

# %%
df.isna().sum().plot.bar()
# Out:
# <Axes: >

# %%
df.update_datetime
# Out:
# 0       2014-05-22 09:09:04.145
# 1       2014-05-22 09:09:04.145
# 2       2014-05-22 09:09:04.145
# 3       2014-05-22 09:09:04.145
# 4       2014-05-22 09:09:04.145
#                   ...
# 55259   2014-11-04 14:13:47.581
# 55260   2014-11-04 14:13:47.581
# 55261   2014-11-04 14:13:47.581
# 55262   2014-11-04 14:13:47.581
# 55263   2014-11-04 14:13:47.581
# Name: update_datetime, Length: 55264, dtype: datetime64[ns]

# %%
unique_garagecodes = df['garagecode'].unique().tolist()

# %%
# 8 individual plots
for garage in unique_garagecodes:
    filtered_df = df[df['garagecode'] == garage]

    sns.lineplot(x='update_datetime', y='vehiclecount', data=filtered_df)
    plt.title(garage)
    plt.show()

# %%
# 1 plot with 4x2 subplots

row_count = 4
col_count = 2

sns.set(style='darkgrid')
fig, axes = plt.subplots(nrows=row_count, ncols=col_count, figsize=(12,16))

for i, garage in enumerate(unique_garagecodes):
    row = i // col_count
    col = i % col_count
    filtered_df = df[df['garagecode'] == garage]

    sns.lineplot(x='update_datetime', y='vehiclecount', data=filtered_df, ax=axes[row, col])
    axes[row, col].set_title(garage)

plt.suptitle('Vehicle Count over Time')
plt.tight_layout()
plt.show()

# %%
df.dtypes
# Out:
# vehiclecount                int64
# updatetime                 object
# _id                         int64
# totalspaces                 int64
# garagecode                 object
# streamtime                 object
# update_datetime    datetime64[ns]
# stream_datetime    datetime64[ns]
# dtype: object

# %% [markdown]
# # Adding Day of the Week:

# %%
#add datetime column and separate day and time columns in datetime datatype
df['Datetime'] = pd.to_datetime(df['updatetime'])
df['date'] = df['Datetime'].dt.date
df['time'] = df['Datetime'].dt.time

# %%
df.columns
# Out:
# Index(['_id', 'updatetime', 'streamtime', 'Datetime', 'date', 'time',
#        'vehiclecount', 'totalspaces', 'garagecode', 'weekday', 'weekday_name'],
#       dtype='object')

# %%
# Out:
#    _id               updatetime           streamtime                Datetime  \
# 0    1  2014-05-22 09:09:04.145  2014-11-03 16:18:44 2014-05-22 09:09:04.145
# 1    2  2014-05-22 09:09:04.145  2014-11-03 16:18:44 2014-05-22 09:09:04.145
# 2    3  2014-05-22 09:09:04.145  2014-11-03 16:18:44 2014-05-22 09:09:04.145
# 3    4  2014-05-22 09:09:04.145  2014-11-03 16:18:44 2014-05-22 09:09:04.145
# 4    5  2014-05-22 09:09:04.145  2014-11-03 16:18:44 2014-05-22 09:09:04.145
#
#          date             time  vehiclecount  totalspaces    garagecode
# 0  2014-05-22  09:09:04.145000             0           65     NORREPORT
# 1  2014-05-22  09:09:04.145000             0          512   SKOLEBAKKEN
# 2  2014-05-22  09:09:04.145000           869         1240   SCANDCENTER
# 3  2014-05-22  09:09:04.145000            22          953        BRUUNS
# 4  2014-05-22  09:09:04.145000           124          130  BUSGADEHUSET

# %%
df['date'] = pd.to_datetime(df['date'])
df['weekday'] = df['date'].dt.dayofweek
weekday_names = {0: 'Monday', 1: 'Tuesday', 2: 'Wednesday', 3: 'Thursday',
                 4: 'Friday', 5: 'Saturday', 6: 'Sunday'}
df['weekday_name'] = df['weekday'].map(weekday_names)
df.head()
# Out:
#    _id               updatetime           streamtime                Datetime  \
# 0    1  2014-05-22 09:09:04.145  2014-11-03 16:18:44 2014-05-22 09:09:04.145
# 1    2  2014-05-22 09:09:04.145  2014-11-03 16:18:44 2014-05-22 09:09:04.145
# 2    3  2014-05-22 09:09:04.145  2014-11-03 16:18:44 2014-05-22 09:09:04.145
# 3    4  2014-05-22 09:09:04.145  2014-11-03 16:18:44 2014-05-22 09:09:04.145
# 4    5  2014-05-22 09:09:04.145  2014-11-03 16:18:44 2014-05-22 09:09:04.145
#
#         date             time weekday_name  vehiclecount  totalspaces  \
# 0 2014-05-22  09:09:04.145000     Thursday             0           65
# 1 2014-05-22  09:09:04.145000     Thursday             0          512
# 2 2014-05-22  09:09:04.145000     Thursday           869         1240
# 3 2014-05-22  09:09:04.145000     Thursday            22          953
# 4 2014-05-22  09:09:04.145000     Thursday           124          130
#
#      garagecode  weekday
# 0     NORREPORT        3
# 1   SKOLEBAKKEN        3
# 2   SCANDCENTER        3
# 3        BRUUNS        3
# 4  BUSGADEHUSET        3

# %%
order = ['_id','updatetime', 'streamtime', 'Datetime', 'date', 'time','weekday', 'weekday_name','vehiclecount', 'totalspaces', 'garagecode']
df = df[order]
df.head()
# Out:
#    _id               updatetime           streamtime                Datetime  \
# 0    1  2014-05-22 09:09:04.145  2014-11-03 16:18:44 2014-05-22 09:09:04.145
# 1    2  2014-05-22 09:09:04.145  2014-11-03 16:18:44 2014-05-22 09:09:04.145
# 2    3  2014-05-22 09:09:04.145  2014-11-03 16:18:44 2014-05-22 09:09:04.145
# 3    4  2014-05-22 09:09:04.145  2014-11-03 16:18:44 2014-05-22 09:09:04.145
# 4    5  2014-05-22 09:09:04.145  2014-11-03 16:18:44 2014-05-22 09:09:04.145
#
#         date             time  weekday weekday_name  vehiclecount  \
# 0 2014-05-22  09:09:04.145000        3     Thursday             0
# 1 2014-05-22  09:09:04.145000        3     Thursday             0
# 2 2014-05-22  09:09:04.145000        3     Thursday           869
# 3 2014-05-22  09:09:04.145000        3     Thursday            22
# 4 2014-05-22  09:09:04.145000        3     Thursday           124
#
#    totalspaces    garagecode
# 0           65     NORREPORT
# 1          512   SKOLEBAKKEN
# 2         1240   SCANDCENTER
# 3          953        BRUUNS
# 4          130  BUSGADEHUSET

# %%
#df.to_csv('parking_data.csv', index=False)
